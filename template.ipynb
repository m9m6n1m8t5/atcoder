# %% [markdown]
# # template

# %% [markdown]
# ## A

# %%
IN = iter(Input.split("\n")).__next__
def input():
    return IN()

# ------------------------------------------------------

# %%
from ipywidgets import Textarea
def get_input(change):
    global Input
    Input = change["new"]

textarea = Textarea()
textarea.observe(get_input, names="value")
display(textarea)
# Out:
# Textarea(value='')

# %% [markdown]
# ## B

# %%
IN = iter(Input.split("\n")).__next__
def input():
    return IN()

# ------------------------------------------------------

# %%
from ipywidgets import Textarea
def get_input(change):
    global Input
    Input = change["new"]

textarea = Textarea()
textarea.observe(get_input, names="value")
display(textarea)
# Out:
# Textarea(value='')

# %% [markdown]
# ## C

# %%
IN = iter(Input.split("\n")).__next__
def input():
    return IN()

# ------------------------------------------------------

# %%
from ipywidgets import Textarea
def get_input(change):
    global Input
    Input = change["new"]

textarea = Textarea()
textarea.observe(get_input, names="value")
display(textarea)
# Out:
# Textarea(value='')

# %% [markdown]
# ## D

# %%
IN = iter(Input.split("\n")).__next__
def input():
    return IN()

# ------------------------------------------------------

# %%
from ipywidgets import Textarea
def get_input(change):
    global Input
    Input = change["new"]

textarea = Textarea()
textarea.observe(get_input, names="value")
display(textarea)
# Out:
# Textarea(value='')

# %% [markdown]
# ## E
