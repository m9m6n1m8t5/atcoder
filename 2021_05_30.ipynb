# %% [markdown]
# # template

# %% [markdown]
# ## A

# %%
IN = iter(Input.split("\n")).__next__
def input():
    return IN()

# ------------------------------------------------------

a = list(map(int, input().split()))
for i in range(3):
    if a[i] == a[i-1]:
        print(a[i-2])
        break
    elif i==2:
        print(0)
# Out:
# 2

# %%
from ipywidgets import Textarea
def get_input(change):
    global Input
    Input = change["new"]

textarea = Textarea()
textarea.observe(get_input, names="value")
display(textarea)
# Out:
# Textarea(value='')

# %% [markdown]
# ## B

# %%
IN = iter(Input.split("\n")).__next__
def input():
    return IN()

# ------------------------------------------------------

N, K = list(map(int, input().split()))
print(N*(N+1)//2*100*K + K*(K+1)//2*N)
# Out:
# 1818

# %%
from ipywidgets import Textarea
def get_input(change):
    global Input
    Input = change["new"]

textarea = Textarea()
textarea.observe(get_input, names="value")
display(textarea)
# Out:
# Textarea(value='')

# %% [markdown]
# ## C

# %%
IN = iter(Input.split("\n")).__next__
def input():
    return IN()

# ------------------------------------------------------
# Out:
# [9 8 7 6 5 4 3 2 1]
# 5
# 5

# %%
from ipywidgets import Textarea
def get_input(change):
    global Input
    Input = change["new"]

textarea = Textarea()
textarea.observe(get_input, names="value")
display(textarea)
# Out:
# Textarea(value='')

# %% [markdown]
# ## D

# %%
IN = iter(Input.split("\n")).__next__
def input():
    return IN()

# ------------------------------------------------------
import numpy as np
N, K = list(map(int, input().split()))
A = np.array([list(map(int, input().split())) for _ in range(N)])
ans = 10**9
for i in range(N-K+1):
    for j in range(N-K+1):
        sub_A = A[i:i+K, j:j+K].reshape(-1)

        median = np.sort(sub_A)[::-1][K*K//2]
        if ans > median:
            ans = median
print(median)
# Out:
# 4 2 [0, 2, 2, 2, 0]
# 2 0 [2, 2, 2, 2, 0]
# 1 2 [2, 2, 1, 2, 0]
# 1 1 [2, 1, 1, 2, 0]

# %%
from ipywidgets import Textarea
def get_input(change):
    global Input
    Input = change["new"]

textarea = Textarea()
textarea.observe(get_input, names="value")
display(textarea)
# Out:
# Textarea(value='')

# %% [markdown]
# ## E

# %%
row
# Out:
# [0, 0, 1, 0, 0]
